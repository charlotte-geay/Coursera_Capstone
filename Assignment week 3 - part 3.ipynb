# %% [markdown]
# # Webscraping of Toronto districts

# %% [markdown]
# ## Part 1 : data on boroughs

# %% [markdown]
# ### Importation of libraries

# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Scraping of the relevant Wikipedia page

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# ### Data formatting

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

df.head()
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government

# %%
# Size of the data
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2 - Find longitude and latitude

# %%
#Ajout des colonnes à compléter
df['Latitude'] = 0
df['Longitude'] = 0
df.head()
# Out:
#   PostalCode           Borough                      Neighborhood  Latitude  \
# 0        M3A        North York                         Parkwoods         0
# 1        M4A        North York                  Victoria Village         0
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront         0
# 3        M6A        North York  Lawrence Manor, Lawrence Heights         0
# 4        M7A      Queen's Park     Ontario Provincial Government         0
#
#    Longitude
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# On fait la requête en utilisant l'API google pour localiser (les exemples donnés dans le cours ne semblent pas convenir). Cela nécessite une clef API qui n'est pas rendue publique car donne le droit à un nombre limité de requêtes.

# %%
import requests

API_KEY_GOOGLE = 'AIzaSyAMQtbchHLkdagOt1uc_mGtecOLE7p6lIo'

for cp in df['PostalCode']:
    req = 'https://maps.googleapis.com/maps/api/geocode/json?address='+cp+', Toronto&key='+API_KEY_GOOGLE
    r = requests.get(req)
    r = r.json()
    df.loc[df['PostalCode'] == cp, 'Latitude'] = r['results'][0]['geometry']['location']['lat']
    df.loc[df['PostalCode'] == cp, 'Longitude'] = r['results'][0]['geometry']['location']['lng']
df.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# ## Part 3 : Clustering the neighborhoods in Toronto

# %%
# Installation de la librairie Folium
# !conda install -c conda-forge folium --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# On crée une carte de Toronto où on localise les différents codes postaux

# %%
import folium 
req = 'https://maps.googleapis.com/maps/api/geocode/json?address=Toronto&key='+API_KEY_GOOGLE
r = requests.get(req).json()
map_toronto = folium.Map(location=[r['results'][0]['geometry']['location']['lat'], r['results'][0]['geometry']['location']['lng']], zoom_start=10)

for lat, lng, borough, pc in zip(df['Latitude'], df['Longitude'], df['Borough'], df['PostalCode']):
    label = '{} : {}'.format(pc, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6d40d7120ae1404bb7b5639a07be1a86%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6d40d7120ae1404bb7b5639a07be1a86%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6d40d7120ae1404bb7b5639a07be1a86%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6d40d7120ae1404bb7b5639a07be1a86%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.653226%2C%20-79.3831843%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Foursquare API

CLIENT_ID = 'SGUEN0WZBU3P34MKPYOQA2TSTWHIBEZ5PVNXSOYZD0MK2HXZ' # your Foursquare ID
CLIENT_SECRET = '4WWZK1JEOUFDSJPHB2CIKDOUK1JSQCN01GBMBHV1KJIUWVVE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SGUEN0WZBU3P34MKPYOQA2TSTWHIBEZ5PVNXSOYZD0MK2HXZ
# CLIENT_SECRET:4WWZK1JEOUFDSJPHB2CIKDOUK1JSQCN01GBMBHV1KJIUWVVE

# %%
df.loc[0, 'Neighborhood']
neighborhood_latitude = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = df.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = df.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))

# type your answer here
url = 'https://api.foursquare.com/v2/venues/explore?&client_id='+CLIENT_ID+'&client_secret='+CLIENT_SECRET+'&v='+VERSION+'&ll='+str(neighborhood_latitude)+','+str(neighborhood_longitude)+'&radius=5000&limit=100'
url

results = requests.get(url).json()
results
# Out:
# Latitude and longitude values of Parkwoods are 43.7532586, -79.3296565.
# {'meta': {'code': 200, 'requestId': '61085a5e24aae1771b8a5571'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Toronto',
#   'headerFullLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'totalResults': 219,
#   'suggestedBounds': {'ne': {'lat': 43.79825864500005,
#     'lng': -79.26747389849278},
#    'sw': {'lat': 43.70825855499996, 'lng': -79.39183910150722}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8991cbf964a520814232e3',
#        'name': "Allwyn's Bakery",
#        'location': {'address': '81 Underhill drive',
#         'lat': 43.75984035203157,
#         'lng': -79.32471879917513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75984035203157,
#           'lng': -79.32471879917513}],
#         'distance': 833,
#         'postalCode': 'M3A 1Z5',
#         'cc': 'CA',
#         'neighborhood': 'Parkwoods - Donalda',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['81 Underhill drive',
#          'Toronto ON M3A 1Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8991cbf964a520814232e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd4846a6798ef3bd0c5618d',
#        'name': 'Donalda Golf & Country Club',
#        'location': {'address': '12 Bushbury Dr',
#         'lat': 43.75281596740471,
#         'lng': -79.34274125604858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75281596740471,
#           'lng': -79.34274125604858}],
#         'distance': 1053,
#         'postalCode': 'M3A 2Z7',
#         'cc': 'CA',
#         'city': 'Don Mills',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['12 Bushbury Dr',
#          'Don Mills ON M3A 2Z7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e6941735',
#          'name': 'Golf Course',
#          'pluralName': 'Golf Courses',
#          'shortName': 'Golf Course',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd4846a6798ef3bd0c5618d-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8ec91af964a520053733e3',
#        'name': 'Graydon Hall Manor',
#        'location': {'address': '185 Graydon Hall Drive',
#         'lat': 43.76392256055678,
#         'lng': -79.34296075662587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76392256055678,
#           'lng': -79.34296075662587}],
#         'distance': 1597,
#         'postalCode': 'M3A 3B4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['185 Graydon Hall Drive',
#          'Toronto ON M3A 3B4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'shortName': 'Event Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52496423'}},
#       'referralId': 'e-0-4b8ec91af964a520053733e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0aed06f964a520202a23e3',
#        'name': 'Island Foods',
#        'location': {'address': '1310 Don Mills Rd.',
#         'lat': 43.745866073988985,
#         'lng': -79.34603533317939,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.745866073988985,
#           'lng': -79.34603533317939}],
#         'distance': 1553,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1310 Don Mills Rd.', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0aed06f964a520202a23e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccec87654f0b1f7f32824ca',
#        'name': 'Galleria Supermarket',
#        'location': {'address': '865 York Mills Rd.',
#         'crossStreet': 'at Upjohn Rd.',
#         'lat': 43.75352001200256,
#         'lng': -79.34951815337949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75352001200256,
#           'lng': -79.34951815337949}],
#         'distance': 1597,
#         'postalCode': 'M3B 1Y5',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['865 York Mills Rd. (at Upjohn Rd.)',
#          'Toronto ON M3B 1Y5',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccec87654f0b1f7f32824ca-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a8743ed1543c734d2840194',
#        'name': 'Starbucks Reserve Bar',
#        'location': {'address': '1090 Don Mills Rd',
#         'crossStreet': 'at Lawrence Ave',
#         'lat': 43.735764352650975,
#         'lng': -79.34415591212019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.735764352650975,
#           'lng': -79.34415591212019}],
#         'distance': 2269,
#         'postalCode': 'M3C 0H1',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1090 Don Mills Rd (at Lawrence Ave)',
#          'Toronto ON M3C 0H1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a8743ed1543c734d2840194-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519e5c39498eb25c945e98c8',
#        'name': 'VIA CIBO | italian streetfood',
#        'location': {'address': '808 York Mills Rd, Unit 14',
#         'crossStreet': 'Leslie St',
#         'lat': 43.75406686431253,
#         'lng': -79.35795099741557,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75406686431253,
#           'lng': -79.35795099741557}],
#         'distance': 2276,
#         'postalCode': 'M3B 1X8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['808 York Mills Rd, Unit 14 (Leslie St)',
#          'Toronto ON M3B 1X8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519e5c39498eb25c945e98c8-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b94d646f964a520c58434e3',
#        'name': 'Mindset by Design',
#        'location': {'address': '6A-170 The Donway West, Suite 714',
#         'crossStreet': 'Don Mills & Lawrence',
#         'lat': 43.735379301987614,
#         'lng': -79.34784293174744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.735379301987614,
#           'lng': -79.34784293174744}],
#         'distance': 2469,
#         'postalCode': 'M3C 2E8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['6A-170 The Donway West, Suite 714 (Don Mills & Lawrence)',
#          'Toronto ON M3C 2E8',
#          'Canada']},
#        'categories': [{'id': '54541900498ea6ccd0202697',
#          'name': 'Health & Beauty Service',
#          'pluralName': 'Health & Beauty Services',
#          'shortName': 'Health & Beauty',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '48882050'}},
#       'referralId': 'e-0-4b94d646f964a520c58434e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e11eea96284edb6badbaa31',
#        'name': 'Aroma Espresso Bar',
#        'location': {'address': '1090 Don Mills Rd.',
#         'crossStreet': 'Shops at Don Mills',
#         'lat': 43.73439968185306,
#         'lng': -79.3452038090861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73439968185306,
#           'lng': -79.3452038090861}],
#         'distance': 2443,
#         'postalCode': 'M3C 3R6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1090 Don Mills Rd. (Shops at Don Mills)',
#          'Toronto ON M3C 3R6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e11eea96284edb6badbaa31-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc795d215a7ef3b97b279da',
#        'name': 'CF Shops at Don Mills',
#        'location': {'address': '1090 Don Mills Rd.',
#         'crossStreet': 'at Lawrence Ave E',
#         'lat': 43.73501112909844,
#         'lng': -79.34478724407985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73501112909844,
#           'lng': -79.34478724407985}],
#         'distance': 2367,
#         'postalCode': 'M3C 3R6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1090 Don Mills Rd. (at Lawrence Ave E)',
#          'Toronto ON M3C 3R6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc795d215a7ef3b97b279da-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b0b5df964a520edee2be3',
#        'name': 'What a Bagel',
#        'location': {'address': '808 York Mills Rd',
#         'lat': 43.754330081991476,
#         'lng': -79.35746465464855,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.754330081991476,
#           'lng': -79.35746465464855}],
#         'distance': 2239,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['808 York Mills Rd', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b0b5df964a520edee2be3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c18e819d4d9c9284e19f029',
#        'name': 'LA Fitness',
#        'location': {'address': '1380 Don Mills Road',
#         'crossStreet': 'Mallard Rd',
#         'lat': 43.74766522888878,
#         'lng': -79.34707696065234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74766522888878,
#           'lng': -79.34707696065234}],
#         'distance': 1532,
#         'postalCode': 'M3B 2X2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1380 Don Mills Road (Mallard Rd)',
#          'Toronto ON M3B 2X2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c18e819d4d9c9284e19f029-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd19e051838a75196486487',
#        'name': 'Ghadir Mid-Eastern Grocery',
#        'location': {'address': '1821 Lawrence Ave E',
#         'crossStreet': 'Pharmacy Ave',
#         'lat': 43.74363845933303,
#         'lng': -79.30423348681926,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74363845933303,
#           'lng': -79.30423348681926}],
#         'distance': 2307,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1821 Lawrence Ave E (Pharmacy Ave)',
#          'Toronto ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd19e051838a75196486487-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b149ea4f964a52029a523e3',
#        'name': 'Darband Restaurant',
#        'location': {'address': '879 York Mills Rd',
#         'lat': 43.755193955394894,
#         'lng': -79.34849758596626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.755193955394894,
#           'lng': -79.34849758596626}],
#         'distance': 1530,
#         'postalCode': 'M3B 1Y5',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['879 York Mills Rd',
#          'Toronto ON M3B 1Y5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b149ea4f964a52029a523e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd56bc194848cfa2b1ae6b1',
#        'name': 'Kostas Meat Market',
#        'location': {'address': '259 Ellesmere Rd',
#         'crossStreet': 'Warden Ave',
#         'lat': 43.7606051148729,
#         'lng': -79.30182964378845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7606051148729,
#           'lng': -79.30182964378845}],
#         'distance': 2382,
#         'postalCode': 'M1R 4E4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['259 Ellesmere Rd (Warden Ave)',
#          'Toronto ON M1R 4E4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd56bc194848cfa2b1ae6b1-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57e286f2498e43d84d92d34a',
#        'name': 'Tim Hortons',
#        'location': {'address': '215 Brookbanks',
#         'crossStreet': 'York Miils Rd',
#         'lat': 43.76066827030228,
#         'lng': -79.32636763515987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.76066827030228,
#           'lng': -79.32636763515987}],
#         'distance': 866,
#         'postalCode': 'M3A 1Z5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['215 Brookbanks (York Miils Rd)',
#          'Toronto ON M3A 1Z5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57e286f2498e43d84d92d34a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ae494c11d2b6f249bfeaac',
#        'name': 'Chipotle Mexican Grill',
#        'location': {'address': '1072 Don Mills Rd',
#         'crossStreet': 'Don Mills & Lawrence',
#         'lat': 43.73521,
#         'lng': -79.34396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73521,
#           'lng': -79.34396}],
#         'distance': 2315,
#         'postalCode': 'M3C 0H8',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1072 Don Mills Rd (Don Mills & Lawrence)',
#          'Toronto ON M3C 0H8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ae494c11d2b6f249bfeaac-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '500982f0e4b034274e8373e8',
#        'name': 'Naan & Kabob Halal',
#        'location': {'address': '1801 Lawrence Ave East',
#         'crossStreet': 'Pharmacy Ave',
#         'lat': 43.74290326259434,
#         'lng': -79.30514824489153,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74290326259434,
#           'lng': -79.30514824489153}],
#         'distance': 2283,
#         'postalCode': 'M1R 2X9',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1801 Lawrence Ave East (Pharmacy Ave)',
#          'Scarborough ON M1R 2X9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-500982f0e4b034274e8373e8-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e94e22498ef46928218339',
#        'name': 'Cineplex Cinemas',
#        'location': {'address': '12 Marie Labatte Road',
#         'lat': 43.73427877090645,
#         'lng': -79.34616425228229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73427877090645,
#           'lng': -79.34616425228229}],
#         'distance': 2495,
#         'postalCode': 'M3C 0H9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['12 Marie Labatte Road',
#          'Toronto ON M3C 0H9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'events': {'count': 5, 'summary': '5 movies'},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53e94e22498ef46928218339-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4fd4a9f964a520fd1627e3',
#        'name': 'North Beach Indoor Volleyball Academy',
#        'location': {'address': '74 Railside Rd',
#         'lat': 43.73719098696113,
#         'lng': -79.32371442851704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73719098696113,
#           'lng': -79.32371442851704}],
#         'distance': 1851,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['74 Railside Rd', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4fd4a9f964a520fd1627e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4cb66cf964a52065bb26e3',
#        'name': 'Shawarma Empire',
#        'location': {'address': '1823 Lawrence Ave. E',
#         'crossStreet': 'at Pharmacy Ave.',
#         'lat': 43.743405300438305,
#         'lng': -79.30364913090075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.743405300438305,
#           'lng': -79.30364913090075}],
#         'distance': 2361,
#         'postalCode': 'M1R 2Y3',
#         'cc': 'CA',
#         'neighborhood': 'Wexford',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1823 Lawrence Ave. E (at Pharmacy Ave.)',
#          'Scarborough ON M1R 2Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4cb66cf964a52065bb26e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0abe03340720a199028793',
#        'name': 'Pho Metro',
#        'location': {'address': '2057 Lawrence Ave E',
#         'crossStreet': 'at Warden',
#         'lat': 43.74536458313563,
#         'lng': -79.29446212828603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74536458313563,
#           'lng': -79.29446212828603}],
#         'distance': 2963,
#         'postalCode': 'M1R 2Z4',
#         'cc': 'CA',
#         'city': 'Toronto Division',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2057 Lawrence Ave E (at Warden)',
#          'Toronto Division ON M1R 2Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0abe03340720a199028793-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b55e81498e6b087da5f439',
#        'name': 'Me Va Me Kitchen Express',
#        'location': {'address': '860 York Mills Rd',
#         'crossStreet': 'Lesmill Rd',
#         'lat': 43.754957495624346,
#         'lng': -79.3518944966201,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.754957495624346,
#           'lng': -79.3518944966201}],
#         'distance': 1798,
#         'postalCode': 'M3B 1Y4',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['860 York Mills Rd (Lesmill Rd)',
#          'Toronto ON M3B 1Y4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54b55e81498e6b087da5f439-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '550df684498ea2dd2c87bb5a',
#        'name': 'Jatujak',
#        'location': {'address': '1744  Victoria Park',
#         'crossStreet': 'Surrey Ave',
#         'lat': 43.736207542145884,
#         'lng': -79.30766830088342,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.736207542145884,
#           'lng': -79.30766830088342}],
#         'distance': 2594,
#         'postalCode': 'M1R 1R4',
#         'cc': 'CA',
#         'neighborhood': 'Victoria Park Village, Toronto, ON',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1744  Victoria Park (Surrey Ave)',
#          'North York ON M1R 1R4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-550df684498ea2dd2c87bb5a-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd631a75631c9b6998fa530',
#        'name': 'Edwards Gardens',
#        'location': {'address': '755 Lawrence Ave E',
#         'lat': 43.73357397323459,
#         'lng': -79.35832879576286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73357397323459,
#           'lng': -79.35832879576286}],
#         'distance': 3180,
#         'postalCode': 'M3C 1P2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['755 Lawrence Ave E',
#          'Toronto ON M3C 1P2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd631a75631c9b6998fa530-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0ec556f964a520c95a23e3',
#        'name': 'Congee Queen 皇后名粥',
#        'location': {'address': '895 Lawrence Ave. E',
#         'crossStreet': 'at Don Mills Rd.',
#         'lat': 43.735977372912316,
#         'lng': -79.34735561803191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.735977372912316,
#           'lng': -79.34735561803191}],
#         'distance': 2393,
#         'postalCode': 'M37 3L2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['895 Lawrence Ave. E (at Don Mills Rd.)',
#          'Toronto ON M37 3L2',
#          'Canada']},
#        'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#          'name': 'Cantonese Restaurant',
#          'pluralName': 'Cantonese Restaurants',
#          'shortName': 'Cantonese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0ec556f964a520c95a23e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c02b933310fc9b64fe1c461',
#        'name': 'JOEY Don mills',
#        'location': {'address': "75 O'Neill Rd",
#         'lat': 43.733990328997315,
#         'lng': -79.34473422057377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.733990328997315,
#           'lng': -79.34473422057377}],
#         'distance': 2463,
#         'postalCode': 'M3C 0H2',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["75 O'Neill Rd",
#          'North York ON M3C 0H2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c02b933310fc9b64fe1c461-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c00004ff61ea5933223eb13',
#        'name': 'Aga Khan Museum',
#        'location': {'address': '77 Wynford Dr',
#         'crossStreet': 'at Don Valley Pkwy',
#         'lat': 43.725105344569876,
#         'lng': -79.33207588784165,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.725105344569876,
#           'lng': -79.33207588784165}],
#         'distance': 3140,
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['77 Wynford Dr (at Don Valley Pkwy)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '42645770'}},
#       'referralId': 'e-0-4c00004ff61ea5933223eb13-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b461b62f964a5209b1626e3',
#        'name': 'Le Cafe Michi',
#        'location': {'address': '1802 Pharmacy Ave',
#         'crossStreet': 'at Sheppard Ave E',
#         'lat': 43.775837053094016,
#         'lng': -79.31761690899509,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.775837053094016,
#           'lng': -79.31761690899509}],
#         'distance': 2693,
#         'postalCode': 'M1T 1A1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1802 Pharmacy Ave (at Sheppard Ave E)',
#          'Toronto ON M1T 1A1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b461b62f964a5209b1626e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdccf4cafe8c9b6da285185',
#        'name': 'LCBO',
#        'location': {'address': 'Parkway Mall',
#         'crossStreet': '5 Ellesmere Rd.',
#         'lat': 43.75777384662435,
#         'lng': -79.31425673330513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.75777384662435,
#           'lng': -79.31425673330513}],
#         'distance': 1336,
#         'postalCode': 'M1R 4B7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Parkway Mall (5 Ellesmere Rd.)',
#          'Toronto ON M1R 4B7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdccf4cafe8c9b6da285185-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad771f0f964a520900a21e3',
#        'name': 'The Keg Steakhouse + Bar - Leslie Street',
#        'location': {'address': '1977 Leslie Street',
#         'lat': 43.758797847809696,
#         'lng': -79.36074935128283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.758797847809696,
#           'lng': -79.36074935128283}],
#         'distance': 2574,
#         'postalCode': 'M3B 2M3',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1977 Leslie Street',
#          'Toronto ON M3B 2M3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1359972024'}},
#       'referralId': 'e-0-4ad771f0f964a520900a21e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc4a69cb492d13a6554aa60',
#        'name': 'Tasty Shawarma & Falafel',
#        'location': {'address': '2993 Sheppard Ave. E',
#         'crossStreet': 'at Pharmacy Ave',
#         'lat': 43.776126433586356,
#         'lng': -79.31842358888973,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.776126433586356,
#           'lng': -79.31842358888973}],
#         'distance': 2701,
#         'postalCode': 'M1T 3J5',
#         'cc': 'CA',
#         'city': 'Toronto Division',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2993 Sheppard Ave. E (at Pharmacy Ave)',
#          'Toronto Division ON M1T 3J5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc4a69cb492d13a6554aa60-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7c2be9f964a520e7812fe3',
#        'name': 'Toronto Botanical Garden',
#        'location': {'address': '777 Lawrence Avenue East',
#         'crossStreet': 'Leslie St.',
#         'lat': 43.73410440082706,
#         'lng': -79.35832146261272,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73410440082706,
#           'lng': -79.35832146261272}],
#         'distance': 3140,
#         'postalCode': 'M3C 1P2',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['777 Lawrence Avenue East (Leslie St.)',
#          'Toronto ON M3C 1P2',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a22',
#          'name': 'Botanical Garden',
#          'pluralName': 'Botanical Gardens',
#          'shortName': 'Botanical Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/botanicalgarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7c2be9f964a520e7812fe3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb0f805f964a520c66e3ce3',
#        'name': 'Arz Fine Foods',
#        'location': {'address': '1909 Lawrence Ave E',
#         'lat': 43.74389829414246,
#         'lng': -79.30099567107857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74389829414246,
#           'lng': -79.30099567107857}],
#         'distance': 2529,
#         'postalCode': 'M1R 2Y6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1909 Lawrence Ave E',
#          'Toronto ON M1R 2Y6',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb0f805f964a520c66e3ce3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53bafb4f498eb927faa3cd9e',
#        'name': 'Matsuda Japanese Cuisine & Teppanyaki',
#        'location': {'address': '1300 Don Mills Rd #2',
#         'lat': 43.74549366550305,
#         'lng': -79.34582141079446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74549366550305,
#           'lng': -79.34582141079446}],
#         'distance': 1561,
#         'postalCode': 'M3B 2W6',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1300 Don Mills Rd #2',
#          'North York ON M3B 2W6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53bafb4f498eb927faa3cd9e-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0bf09d3bc0b60c7e5bd174',
#        'name': 'Damas Grillhouse & Juice Bar',
#        'location': {'address': '1795 Victoria Park Ave',
#         'crossStreet': 'Lawrence',
#         'lat': 43.74183944758683,
#         'lng': -79.30929636830312,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74183944758683,
#           'lng': -79.30929636830312}],
#         'distance': 2072,
#         'postalCode': 'M1R 1H5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1795 Victoria Park Ave (Lawrence)',
#          'Toronto ON M1R 1H5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0bf09d3bc0b60c7e5bd174-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c3ae15e4b08c3b596c6069',
#        'name': 'Baretto Caffé',
#        'location': {'address': '1262 Don Mills Rd',
#         'lat': 43.74445646349851,
#         'lng': -79.34645978471785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74445646349851,
#           'lng': -79.34645978471785}],
#         'distance': 1669,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1262 Don Mills Rd', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c3ae15e4b08c3b596c6069-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be8b576d837c9b6e2b6a506',
#        'name': 'Makkalchon Korean Restaurant 맛깔촌',
#        'location': {'address': '1979 Lawrence Ave. E',
#         'crossStreet': 'Warden Ave.',
#         'lat': 43.74494499908732,
#         'lng': -79.2964935606234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.74494499908732,
#           'lng': -79.2964935606234}],
#         'distance': 2822,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1979 Lawrence Ave. E (Warden Ave.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be8b576d837c9b6e2b6a506-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52dab7c3498e124cfaf2f43d',
#        'name': 'Lindt & Sprüngli',
#        'location': {'address': '14 Aggie Hogg Gardens',
#         'crossStreet': 'Don Mills Rd',
#         'lat': 43.7348401,
#         'lng': -79.3452689,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7348401,
#           'lng': -79.3452689}],
#         'distance': 2404,
#         'postalCode': 'M3C 0G7',
#         'cc': 'CA',
#         'city': 'North York',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['14 Aggie Hogg Gardens (Don Mills Rd)',
# ...
#          'Toronto ON M2K 2X9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad889bdf964a5201c1221e3-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a9e13eb9ac386d8d34de73',
#        'name': "Baran's Turkish Restaurant & Bar",
#        'location': {'address': '2043 Eglinton Ave E',
#         'lat': 43.72897800106711,
#         'lng': -79.28081055404853,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.72897800106711,
#           'lng': -79.28081055404853}],
#         'distance': 4768,
#         'postalCode': 'M1L 2M9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2043 Eglinton Ave E',
#          'Toronto ON M1L 2M9',
#          'Canada']},
#        'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#          'name': 'Turkish Restaurant',
#          'pluralName': 'Turkish Restaurants',
#          'shortName': 'Turkish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a9e13eb9ac386d8d34de73-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c129019a5eb76b01b69beb7',
#        'name': 'Mr Jerk',
#        'location': {'address': '3050 Don Mills Rd',
#         'lat': 43.78593238518595,
#         'lng': -79.35284203626418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.78593238518595,
#           'lng': -79.35284203626418}],
#         'distance': 4086,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['3050 Don Mills Rd', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c129019a5eb76b01b69beb7-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d137ce89844b60c7c21c3d4',
#        'name': 'PetSmart',
#        'location': {'address': '2050 Eglinton Ave E',
#         'lat': 43.7299452,
#         'lng': -79.2822257,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7299452,
#           'lng': -79.2822257}],
#         'distance': 4613,
#         'postalCode': 'M1L 2M6',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2050 Eglinton Ave E',
#          'Scarborough ON M1L 2M6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d137ce89844b60c7c21c3d4-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d710b811d2a34615719f82',
#        'name': 'Chris Jerk Caribbean Bistro',
#        'location': {'address': '2750 Birchmount Rd',
#         'crossStreet': 'Birchmount & Huntingwood Drive',
#         'lat': 43.78966017950965,
#         'lng': -79.30234015939422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.78966017950965,
#           'lng': -79.30234015939422}],
#         'distance': 4608,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2750 Birchmount Rd (Birchmount & Huntingwood Drive)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76300994'}},
#       'referralId': 'e-0-52d710b811d2a34615719f82-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3843c7f964a5203e4d25e3',
#        'name': 'Shoppers Drug Mart',
#        'location': {'address': '946 Lawrence Ave E,Unit 2',
#         'lat': 43.737261,
#         'lng': -79.345868,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.737261,
#           'lng': -79.345868}],
#         'distance': 2207,
#         'postalCode': 'M3C 1R1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['946 Lawrence Ave E,Unit 2',
#          'Toronto ON M3C 1R1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3843c7f964a5203e4d25e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ada3af3f964a520482021e3',
#        'name': 'CF Fairview Mall',
#        'location': {'address': '1800 Sheppard Ave E',
#         'crossStreet': 'at Don Mills Rd',
#         'lat': 43.77798094562394,
#         'lng': -79.3443966988859,
#         'distance': 2996,
#         'postalCode': 'M2J 5A7',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1800 Sheppard Ave E (at Don Mills Rd)',
#          'Toronto ON M2J 5A7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ada3af3f964a520482021e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54b8669a498e7bffed909876',
#        'name': 'Starbucks',
#        'location': {'address': '1156 Kennedy Rd',
#         'crossStreet': 'At Lawrence Avenue East',
#         'lat': 43.752465,
#         'lng': -79.276364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.752465,
#           'lng': -79.276364}],
#         'distance': 4286,
#         'postalCode': 'M1P 2K9',
#         'cc': 'CA',
#         'neighborhood': 'Dorset Park',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1156 Kennedy Rd (At Lawrence Avenue East)',
#          'Toronto ON M1P 2K9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54b8669a498e7bffed909876-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b707db4f964a520021e2de3',
#        'name': 'McEwan',
#        'location': {'address': '38 Karl Fraser Rd.',
#         'crossStreet': 'in Shops at Don Mills',
#         'lat': 43.73625640025338,
#         'lng': -79.34513152081716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73625640025338,
#           'lng': -79.34513152081716}],
#         'distance': 2265,
#         'postalCode': 'M3C 0H7',
#         'cc': 'CA',
#         'neighborhood': 'Sunnybrook - York Mills',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['38 Karl Fraser Rd. (in Shops at Don Mills)',
#          'Toronto ON M3C 0H7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b707db4f964a520021e2de3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf933d6d76da35df581cb2c',
#        'name': 'LCBO',
#        'location': {'address': '1900 Eglinton Ave E',
#         'crossStreet': 'at Warden Ave',
#         'lat': 43.7292605867195,
#         'lng': -79.2921438674251,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.7292605867195,
#           'lng': -79.2921438674251}],
#         'distance': 4029,
#         'postalCode': 'M1L 2L9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1900 Eglinton Ave E (at Warden Ave)',
#          'Toronto ON M1L 2L9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf933d6d76da35df581cb2c-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53e4f81c498ea330eb42dedb',
#        'name': 'Michaels',
#        'location': {'address': '11 William Kitchen Rd Unit J4',
#         'lat': 43.77461096449904,
#         'lng': -79.28120925504118,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.77461096449904,
#           'lng': -79.28120925504118}],
#         'distance': 4562,
#         'postalCode': 'M1P 5B7',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['11 William Kitchen Rd Unit J4',
#          'Scarborough ON M1P 5B7',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'shortName': 'Arts & Crafts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53e4f81c498ea330eb42dedb-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9bccbef964a520ae2636e3',
#        'name': 'Sultan Of Samosas',
#        'location': {'address': "1677 O'Connor Drive",
#         'lat': 43.71882306937224,
#         'lng': -79.30434985603264,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.71882306937224,
#           'lng': -79.30434985603264}],
#         'distance': 4340,
#         'postalCode': 'M4A 1W5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["1677 O'Connor Drive",
#          'Toronto ON M4A 1W5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9bccbef964a520ae2636e3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c815120d8086dcb40cf6b52',
#        'name': 'Highland Farms',
#        'location': {'address': '850 Ellesmere Rd',
#         'lat': 43.766245521410625,
#         'lng': -79.28313233920433,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.766245521410625,
#           'lng': -79.28313233920433}],
#         'distance': 4010,
#         'postalCode': 'M1P 2W5',
#         'cc': 'CA',
#         'city': 'Scarborough',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['850 Ellesmere Rd',
#          'Scarborough ON M1P 2W5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c815120d8086dcb40cf6b52-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5214b4f964a520506627e3',
#        'name': 'LCBO',
#        'location': {'address': '195 The Donway W',
#         'crossStreet': 'Shops At Don Mills',
#         'lat': 43.73632288176399,
#         'lng': -79.34611450909887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.73632288176399,
#           'lng': -79.34611450909887}],
#         'distance': 2303,
#         'postalCode': 'M3C 0H6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['195 The Donway W (Shops At Don Mills)',
#          'Toronto ON M3C 0H6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'shortName': 'Liquor Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5214b4f964a520506627e3-99'}]}]}}

# %%
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
venues = results['response']['groups'][0]['items']


nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:19: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           name            categories        lat        lng
# 0              Allwyn's Bakery  Caribbean Restaurant  43.759840 -79.324719
# 1  Donalda Golf & Country Club           Golf Course  43.752816 -79.342741
# 2           Graydon Hall Manor           Event Space  43.763923 -79.342961
# 3                 Island Foods  Caribbean Restaurant  43.745866 -79.346035
# 4         Galleria Supermarket           Supermarket  43.753520 -79.349518

# %%
# On écrit une fonction pour "génériquer" ce que l'on vient de faire sur un exemple

def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# On exécute la fonction pour avoir la liste des points d'intérêt
toronto_venues = getNearbyVenues(df['Neighborhood'], 
                df['Latitude'],
                df['Longitude'], 
                radius=5000)
toronto_venues.head()

# %%
# On transforme les données pour mettre les types de lieux en colonnes
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
toronto_onehot.head()

# %%
# On groupe par neighborhood pour avoir la répartition des lieux
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.columns

# %%
import numpy as np

# On regarde les lieux les plus fréquents de chaque zone

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()

# %%
# On passe au clustering
from sklearn.cluster import KMeans

# On définit un nombre de clusters : arbitrairement 5
kclusters = 5

# On enlève la première colonne de la table (qui contient des noms)
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# On fait tourner les clusters
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
print(min(kmeans.labels_))
print(max(kmeans.labels_))

# %%
# Mise en forme des résultats 
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = df

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# On représente les clusters sur une carte

# create map
req = 'https://maps.googleapis.com/maps/api/geocode/json?address=Toronto&key='+API_KEY_GOOGLE
r = requests.get(req).json()
map_clusters = folium.Map(location=[r['results'][0]['geometry']['location']['lat'], r['results'][0]['geometry']['location']['lng']], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
